# %%
from google.colab import drive
drive.mount('/content/drive')

# TODO: 输入你云盘中该作业的路径。(Enter the path in your Drive of the assignment.)
# 例如 'cs231n/assignments/assignment1/'
FOLDERNAME = 'cs231n/assignments/assignment2/'

assert FOLDERNAME is not None, "[!] 请输入文件夹名称。([!] Enter the foldername.)"

import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# %% [markdown]
# # 收集提交内容 - 压缩包 + 产生 PDF
# 一旦你完成了所有其他的笔记本文件，请运行这篇文件：`BatchNormalization.ipynb`, `Dropout.ipynb`, `ConvolutionalNetworks.ipynb` 以及 `PyTorch.ipynb`, `RNN_Captioning_pytorch.ipynb`。
#
# 它将会：
#
# * 将你的代码（`.py` 以及 `.ipynb`）生成为一个以 `a2.zip` 命名的压缩 zip 文件。
# * 将所有的笔记本转化为一个命名为 `assignment.pdf` 的单一 PDF 文件。
#
# 如果你在此步骤通过，你应该能看到以下的信息提示：
#
# `### ### 完成！请将 a2_code_submission.zip 和对应的 pdf 文件提交给 Gradescope。 ### ###`
#
# 确保您将 zip 与 pdf 文件全都下载到你的本地设备计算机之中，然后再进行提交。恭喜你完成了这布置的作业！

# %%
# %cd /content/drive/My\ Drive/$FOLDERNAME
# !sudo apt-get install texlive-xetex texlive-fonts-recommended texlive-plain-generic texlive-latex-extra pandoc --fix-missing
# !pip install PyPDF2
# !bash collectSubmission.sh
